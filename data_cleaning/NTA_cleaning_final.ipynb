# %% [markdown]
# This file is a continuation of my data cleaning / joining after I found easier data to work with.

# %%
import pandas as pd
import geopandas as gpd
from shapely import Point

# %%
census_df = pd.read_csv("../data/nyc_decennialcensusdata_2010_2020_change-core-geographies_v2.csv")

census_df.head()
# Out:
#    Year   GeoType        Borough GeoID  BCT2020       Name CDType  NTAType  \
# 0  2020   NYC2020  New York City     0      NaN        NYC    NaN      NaN
# 1  2020  Boro2020      Manhattan     1      NaN  Manhattan    NaN      NaN
# 2  2020  Boro2020          Bronx     2      NaN      Bronx    NaN      NaN
# 3  2020  Boro2020       Brooklyn     3      NaN   Brooklyn    NaN      NaN
# 4  2020  Boro2020         Queens     4      NaN     Queens    NaN      NaN
#
#         Pop1  Pop1P  ...   ROcHH2  ROcHH2P   ROcHH3  ROcHH3P   ROcHH4  \
# 0  8,804,190  100.0  ...  670,144     28.3  374,447     15.8  263,906
# 1  1,694,251  100.0  ...  196,690     31.4   75,343     12.0   43,007
# 2  1,472,654  100.0  ...  102,118     24.0   77,071     18.1   58,043
# 3  2,736,074  100.0  ...  215,925     29.1  122,906     16.6   84,476
# 4  2,405,464  100.0  ...  139,627     27.6   89,400     17.6   70,538
#
#    ROcHH4P ROcHH5pl  ROcHH5plP LandAcres  LandAcresP
# 0     11.2  254,065       10.7   192,289         NaN
# 1      6.9   27,660        4.4    14,500         NaN
# 2     13.7   61,014       14.4    26,990         NaN
# 3     11.4   89,012       12.0    44,401         NaN
# 4     13.9   68,090       13.4    69,583         NaN
#
# [5 rows x 232 columns]

# %% [markdown]
# So happy to have this cleaned, easy data to work with. I need all rows where GeoType == NTA2020, then I can join it with the geojson file on that column and I'll have my population data like I wanted.
#
# There is plenty of other data about people in these neighborhoods, which may have been of use, but that could be for another time.

# %%
census_clean = census_df.loc[census_df["GeoType"] == "NTA2020", ["GeoID", "Pop1"]]
census_clean.rename(columns={"GeoID": "NTA2020", "Pop1": "Population"}, inplace=True)
census_clean.head()
# Out:
#     NTA2020 Population
# 128  BK0101     38,980
# 129  BK0102     64,444
# 130  BK0103     47,703
# 131  BK0104     52,998
# 132  BK0201     25,092

# %% [markdown]
# Great. This should be fine to merge with the GeoJSON.

# %%
geo_nta = gpd.read_file("../data/NYC_Neighborhood_Tabulation_Areas_2020.geojson")
geo_nta.head()
# Out:
#    OBJECTID  BoroCode  BoroName CountyFIPS NTA2020             NTAName  \
# 0         1         3  Brooklyn        047  BK0101          Greenpoint
# 1         2         3  Brooklyn        047  BK0102        Williamsburg
# 2         3         3  Brooklyn        047  BK0103  South Williamsburg
# 3         4         3  Brooklyn        047  BK0104   East Williamsburg
# 4         5         3  Brooklyn        047  BK0201    Brooklyn Heights
#
#    NTAAbbrev NTAType CDTA2020  \
# 0      Grnpt       0     BK01
# 1   Wllmsbrg       0     BK01
# 2  SWllmsbrg       0     BK01
# 3  EWllmsbrg       0     BK01
# 4      BkHts       0     BK02
#
#                                             CDTAName  \
# 0     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 1     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 2     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 3     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 4  BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...
#
#                                             geometry
# 0  POLYGON ((-73.93214 40.72817, -73.93238 40.728...
# 1  POLYGON ((-73.95814 40.72441, -73.95772 40.724...
# 2  POLYGON ((-73.95024 40.70548, -73.94984 40.705...
# 3  POLYGON ((-73.92406 40.71412, -73.92404 40.714...
# 4  POLYGON ((-73.99237 40.6897, -73.99436 40.6902...

# %%
merged = geo_nta.merge(census_clean, on="NTA2020", how="left")
merged.head()
# Out:
#    OBJECTID  BoroCode  BoroName CountyFIPS NTA2020             NTAName  \
# 0         1         3  Brooklyn        047  BK0101          Greenpoint
# 1         2         3  Brooklyn        047  BK0102        Williamsburg
# 2         3         3  Brooklyn        047  BK0103  South Williamsburg
# 3         4         3  Brooklyn        047  BK0104   East Williamsburg
# 4         5         3  Brooklyn        047  BK0201    Brooklyn Heights
#
#    NTAAbbrev NTAType CDTA2020  \
# 0      Grnpt       0     BK01
# 1   Wllmsbrg       0     BK01
# 2  SWllmsbrg       0     BK01
# 3  EWllmsbrg       0     BK01
# 4      BkHts       0     BK02
#
#                                             CDTAName  \
# 0     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 1     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 2     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 3     BK01 Williamsburg-Greenpoint (CD 1 Equivalent)
# 4  BK02 Downtown Brooklyn-Fort Greene (CD 2 Appro...
#
#                                             geometry Population
# 0  POLYGON ((-73.93214 40.72817, -73.93238 40.728...     38,980
# 1  POLYGON ((-73.95814 40.72441, -73.95772 40.724...     64,444
# 2  POLYGON ((-73.95024 40.70548, -73.94984 40.705...     47,703
# 3  POLYGON ((-73.92406 40.71412, -73.92404 40.714...     52,998
# 4  POLYGON ((-73.99237 40.6897, -73.99436 40.6902...     25,092

# %% [markdown]
# The relief this finally worked! Now to calculate Airbnb per person.

# %%
airbnb = pd.read_csv("../data/airbnb_one_year.csv")
airbnb.head()
# Out:
#                    id                                               name  \
# 0            40824219         Room close to  Manhattan for FEMALE guests
# 1  808629897642520802  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 2  808629343999219473  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 3  808629391209329400  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 4  808629522066886810  Wyndham Midtown 45 Resort | King Bed Studio Suite
#
#      host_id neighbourhood_cleansed neighbourhood_group_cleansed   latitude  \
# 0  317540555              Sunnyside                       Queens  40.746980
# 1  442029804                Midtown                    Manhattan  40.752656
# 2  442029804                Midtown                    Manhattan  40.752656
# 3  442029804                Midtown                    Manhattan  40.752660
# 4  442029804                Midtown                    Manhattan  40.752656
#
#    longitude        room_type    price  minimum_nights  availability_365  \
# 0  -73.91763     Private room   $66.00              30                77
# 1  -73.97248  Entire home/apt  $330.00              30               285
# 2  -73.97248  Entire home/apt  $312.00              30               285
# 3  -73.97248  Entire home/apt      NaN              30               286
# 4  -73.97248  Entire home/apt  $312.00              30               285
#
#   license dataset_date
# 0     NaN   2025-10-01
# 1     NaN   2025-10-01
# 2     NaN   2025-10-01
# 3     NaN   2025-10-01
# 4     NaN   2025-10-01

# %%
airbnb.rename(columns={"neighbourhood_cleansed": "neighborhood_cleansed", "neighbourhood_group_cleansed": "neighborhood_group_cleansed"},
                inplace=True)

# %%
"""
ChatGPT Citation:
I asked "I want to count how many Airbnbs are in a certain NTA. I have the lat and long for each Airbnb, as well as the 
shape file for each neighborhood. How would I do it?
This code was written with the help of its answer.
"""

# create shapely point for each Airbnb 
airbnb["geometry"] = airbnb.apply(lambda row: Point(row["longitude"], row["latitude"]), axis=1)


airbnb_gdf = gpd.GeoDataFrame(airbnb, geometry="geometry", crs="EPSG:4326")

# make sure merged gdf uses same crs
merged = merged.to_crs("EPSG:4326")

# spatial join, assigning each Airbnb to the NTA it falls inside of
joined = gpd.sjoin(airbnb_gdf, merged, how="left", predicate="within")

# count how many are in each NTA
airbnb_counts = joined.groupby("NTA2020").size().reset_index(name="airbnb_count")

airbnb_counts.head()
# Out:
#   NTA2020  airbnb_count
# 0  BK0101           654
# 1  BK0102          1431
# 2  BK0103            48
# 3  BK0104          1081
# 4  BK0201           126

# %%
joined.head()
# Out:
#                    id                                               name  \
# 0            40824219         Room close to  Manhattan for FEMALE guests
# 1  808629897642520802  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 2  808629343999219473  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 3  808629391209329400  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 4  808629522066886810  Wyndham Midtown 45 Resort | King Bed Studio Suite
#
#      host_id neighborhood_cleansed neighborhood_group_cleansed   latitude  \
# 0  317540555             Sunnyside                      Queens  40.746980
# 1  442029804               Midtown                   Manhattan  40.752656
# 2  442029804               Midtown                   Manhattan  40.752656
# 3  442029804               Midtown                   Manhattan  40.752660
# 4  442029804               Midtown                   Manhattan  40.752656
#
#    longitude        room_type    price  minimum_nights  ...  BoroCode  \
# 0  -73.91763     Private room   $66.00              30  ...       4.0
# 1  -73.97248  Entire home/apt  $330.00              30  ...       1.0
# 2  -73.97248  Entire home/apt  $312.00              30  ...       1.0
# 3  -73.97248  Entire home/apt      NaN              30  ...       1.0
# 4  -73.97248  Entire home/apt  $312.00              30  ...       1.0
#
#     BoroName CountyFIPS NTA2020                  NTAName  NTAAbbrev  NTAType  \
# 0     Queens        081  QN0202                Sunnyside     Snnysd        0
# 1  Manhattan        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0
# 2  Manhattan        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0
# 3  Manhattan        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0
# 4  Manhattan        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0
#
#   CDTA2020                                           CDTAName Population
# 0     QN02  QN02 Long Island City-Sunnyside-Woodside (CD 2...     52,278
# 1     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765
# 2     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765
# 3     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765
# 4     MN06  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765
#
# [5 rows x 26 columns]

# %% [markdown]
# Almost there. Now to join the Airbnb counts with the geo dataframe, and calculate the number of Airbnbs based on population.

# %%
NTA_geo_pop = joined.merge(airbnb_counts, on="NTA2020", how="left")

NTA_geo_pop.head()
# Out:
#                    id                                               name  \
# 0            40824219         Room close to  Manhattan for FEMALE guests
# 1  808629897642520802  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 2  808629343999219473  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 3  808629391209329400  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 4  808629522066886810  Wyndham Midtown 45 Resort | King Bed Studio Suite
#
#      host_id neighborhood_cleansed neighborhood_group_cleansed   latitude  \
# 0  317540555             Sunnyside                      Queens  40.746980
# 1  442029804               Midtown                   Manhattan  40.752656
# 2  442029804               Midtown                   Manhattan  40.752656
# 3  442029804               Midtown                   Manhattan  40.752660
# 4  442029804               Midtown                   Manhattan  40.752656
#
#    longitude        room_type    price  minimum_nights  ...   BoroName  \
# 0  -73.91763     Private room   $66.00              30  ...     Queens
# 1  -73.97248  Entire home/apt  $330.00              30  ...  Manhattan
# 2  -73.97248  Entire home/apt  $312.00              30  ...  Manhattan
# 3  -73.97248  Entire home/apt      NaN              30  ...  Manhattan
# 4  -73.97248  Entire home/apt  $312.00              30  ...  Manhattan
#
#   CountyFIPS NTA2020                  NTAName  NTAAbbrev  NTAType  CDTA2020  \
# 0        081  QN0202                Sunnyside     Snnysd        0      QN02
# 1        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0      MN06
# 2        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0      MN06
# 3        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0      MN06
# 4        061  MN0604  East Midtown-Turtle Bay   EstMdtwn        0      MN06
#
#                                             CDTAName Population airbnb_count
# 0  QN02 Long Island City-Sunnyside-Woodside (CD 2...     52,278        337.0
# 1  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765        838.0
# 2  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765        838.0
# 3  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765        838.0
# 4  MN06 East Midtown-Murray Hill (CD 6 Approximat...     45,765        838.0
#
# [5 rows x 27 columns]

# %% [markdown]
# I will use Airbnbs per 10,000, since NTA population sizes are not that large, around 50k people each.

# %%
# drop columns with NaN for population
NTA_geo_pop = NTA_geo_pop.dropna(subset=["Population"])

# remove commas from Population
NTA_geo_pop["Population"] = NTA_geo_pop["Population"].str.replace(",", "")

# fix data type
NTA_geo_pop["Population"] = NTA_geo_pop["Population"].astype(int)

# %%
NTA_geo_pop["airbnb_per_10k"] = round(NTA_geo_pop["airbnb_count"] / NTA_geo_pop["Population"] * 10000, 2)

# %%
NTA_geo_pop.head()
# Out:
#                    id                                               name  \
# 0            40824219         Room close to  Manhattan for FEMALE guests
# 1  808629897642520802  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 2  808629343999219473  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 3  808629391209329400  Wyndham Midtown 45 Resort | King Bed Studio Suite
# 4  808629522066886810  Wyndham Midtown 45 Resort | King Bed Studio Suite
#
#      host_id neighborhood_cleansed neighborhood_group_cleansed   latitude  \
# 0  317540555             Sunnyside                      Queens  40.746980
# 1  442029804               Midtown                   Manhattan  40.752656
# 2  442029804               Midtown                   Manhattan  40.752656
# 3  442029804               Midtown                   Manhattan  40.752660
# 4  442029804               Midtown                   Manhattan  40.752656
#
#    longitude        room_type    price  minimum_nights  ...  CountyFIPS  \
# 0  -73.91763     Private room   $66.00              30  ...         081
# 1  -73.97248  Entire home/apt  $330.00              30  ...         061
# 2  -73.97248  Entire home/apt  $312.00              30  ...         061
# 3  -73.97248  Entire home/apt      NaN              30  ...         061
# 4  -73.97248  Entire home/apt  $312.00              30  ...         061
#
#   NTA2020                  NTAName NTAAbbrev  NTAType  CDTA2020  \
# 0  QN0202                Sunnyside    Snnysd        0      QN02
# 1  MN0604  East Midtown-Turtle Bay  EstMdtwn        0      MN06
# 2  MN0604  East Midtown-Turtle Bay  EstMdtwn        0      MN06
# 3  MN0604  East Midtown-Turtle Bay  EstMdtwn        0      MN06
# 4  MN0604  East Midtown-Turtle Bay  EstMdtwn        0      MN06
#
#                                             CDTAName Population airbnb_count  \
# 0  QN02 Long Island City-Sunnyside-Woodside (CD 2...      52278        337.0
# 1  MN06 East Midtown-Murray Hill (CD 6 Approximat...      45765        838.0
# 2  MN06 East Midtown-Murray Hill (CD 6 Approximat...      45765        838.0
# 3  MN06 East Midtown-Murray Hill (CD 6 Approximat...      45765        838.0
# 4  MN06 East Midtown-Murray Hill (CD 6 Approximat...      45765        838.0
#
#   airbnb_per_10k
# 0          64.46
# 1         183.11
# 2         183.11
# 3         183.11
# 4         183.11
#
# [5 rows x 28 columns]

# %% [markdown]
# I was having issues with extremely large values for Airbnb per 10k. Let me drop anything over 1000 and see if that helps.
#
# The issue may be population as well, for things like parks or airports. Anything under 1000 will get dropped here as well.

# %%
# drop high values for airbnb per 10k
NTA_geo_pop = NTA_geo_pop[NTA_geo_pop["airbnb_per_10k"] <= 1000]

# drop low values for population
NTA_geo_pop = NTA_geo_pop[NTA_geo_pop["Population"] >= 1000]

# %%
sorted_airbnb_10k = NTA_geo_pop["airbnb_per_10k"].sort_values(ascending=False).head()

sorted_airbnb_10k
# Out:
# 45220    607.23
# 38061    607.23
# 38059    607.23
# 17004    607.23
# 42691    607.23
# Name: airbnb_per_10k, dtype: float64

# %% [markdown]
# Also having an issue where Plotly was not recognizing values for NTA2020. It was because there were multiple values for each NTA2020, since each Airbnb had a NTA2020 value. So, I can just make another dataframe with only the NTA2020 and calculated Airbnb per 10k. I also had to include what I want my hover text to be, so I added NTA name and neighborhood group cleansed (borough name).

# %%
NTA_geo_pop["NTA2020"].value_counts().head(10)
# Out:
# NTA2020
# MN0402    1699
# MN0502    1553
# BK0302    1528
# BK0102    1431
# BK0301    1420
# MN0303    1244
# MN0401    1218
# BK0104    1081
# BK0802    1078
# MN0603     974
# Name: count, dtype: int64

# %%
NTA_airbnb_10k = NTA_geo_pop.groupby("NTA2020")[["airbnb_per_10k", "NTAName", "neighborhood_group_cleansed"]].first().reset_index()

NTA_airbnb_10k.head()
# Out:
#   NTA2020  airbnb_per_10k             NTAName neighborhood_group_cleansed
# 0  BK0101          167.78          Greenpoint                    Brooklyn
# 1  BK0102          222.05        Williamsburg                    Brooklyn
# 2  BK0103           10.06  South Williamsburg                    Brooklyn
# 3  BK0104          203.97   East Williamsburg                    Brooklyn
# 4  BK0201           50.22    Brooklyn Heights                    Brooklyn

# %%
# save as .csv for getting the points and stats calculated earlier
# or else it is a mess using a GeoJSON for it
NTA_geo_pop.drop(columns="geometry").to_csv("NTA_stats.csv", index=False)

# and now the .csv for Airbnb per 10k values as well
NTA_airbnb_10k.to_csv("NTA_airbnb_10k.csv")
